# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cars (1).csv")

# %%
df
# Out:
#       mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0    14.0          8         350  165      4209          12  1972       US.
# 1    31.9          4          89   71      1925          14  1980   Europe.
# 2    17.0          8         302  140      3449          11  1971       US.
# 3    15.0          8         400  150      3761          10  1971       US.
# 4    30.5          4          98   63      2051          17  1978       US.
# ..    ...        ...         ...  ...       ...         ...   ...       ...
# 256  17.0          8         305  130      3840          15  1980       US.
# 257  36.1          4          91   60      1800          16  1979    Japan.
# 258  22.0          6         232  112      2835          15  1983       US.
# 259  18.0          6         232  100      3288          16  1972       US.
# 260  22.0          6         250  105      3353          15  1977       US.
#
# [261 rows x 8 columns]

# %%
df.head()
# Out:
#     mpg  cylinders cubicinches   hp weightlbs  time-to-60  year     brand
# 0  14.0          8         350  165      4209          12  1972       US.
# 1  31.9          4          89   71      1925          14  1980   Europe.
# 2  17.0          8         302  140      3449          11  1971       US.
# 3  15.0          8         400  150      3761          10  1971       US.
# 4  30.5          4          98   63      2051          17  1978       US.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  261 non-null    object
#  3   hp           261 non-null    int64
#  4   weightlbs    261 non-null    object
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 16.4+ KB

# %%
df['cubicinches'] = pd.to_numeric(df['cubicinches'], errors = "coerce")
df['weightlbs'] = pd.to_numeric(df['weightlbs'], errors = "coerce")
#'260',"hk",'677'  ====>260,Nan,677

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 261 entries, 0 to 260
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   mpg          261 non-null    float64
#  1   cylinders    261 non-null    int64
#  2   cubicinches  259 non-null    float64
#  3   hp           261 non-null    int64
#  4   weightlbs    258 non-null    float64
#  5   time-to-60   261 non-null    int64
#  6   year         261 non-null    int64
#  7   brand        261 non-null    object
# dtypes: float64(3), int64(4), object(1)
# memory usage: 16.4+ KB

# %%
df.isnull().sum()
# Out:
# mpg            0
# cylinders      0
# cubicinches    2
# hp             0
# weightlbs      3
# time-to-60     0
# year           0
# brand          0
# dtype: int64

# %%
df.shape
# Out:
# (261, 8)

# %%
df.describe()
# Out:
#               mpg   cylinders  cubicinches          hp    weightlbs  \
# count  261.000000  261.000000   259.000000  261.000000   258.000000
# mean    23.144828    5.590038   200.918919  106.360153  3009.833333
# std      7.823570    1.733310   109.258305   40.499959   854.039019
# min     10.000000    3.000000    68.000000   46.000000  1613.000000
# 25%     16.900000    4.000000    99.500000   75.000000  2248.000000
# 50%     22.000000    6.000000   156.000000   95.000000  2867.500000
# 75%     28.800000    8.000000   303.000000  138.000000  3670.000000
# max     46.600000    8.000000   455.000000  230.000000  4997.000000
#
#        time-to-60         year
# count  261.000000   261.000000
# mean    15.547893  1976.819923
# std      2.910625     3.637696
# min      8.000000  1971.000000
# 25%     14.000000  1974.000000
# 50%     16.000000  1977.000000
# 75%     17.000000  1980.000000
# max     25.000000  1983.000000

# %%
df['brand'].value_counts()
# Out:
# brand
#  US.        162
#  Japan.      51
#  Europe.     48
# Name: count, dtype: int64

# %% [markdown]
# # Tasks To Be Performed:

# %% [markdown]
# 1. Create scatter plots for the following data, make sure all the plots appear in the same
# plane with x-labels and y-labels evenly spaced.
#
# a. Create scatter plots with between (mpg-hp, mpg-weight), and (hp-mpg,
# hp-time-to-60) with respect to each brand.

# %%
fig = plt.subplots(2,2, figsize =(20,10))    #(row,columns, figsize=(width,height))
plt.subplot(2,2,1)   #(rows, columns, first plot)
sns.scatterplot(x=df['mpg'], y=df['hp'],data = df,marker='o',s= 100)

plt.subplot(2,2,2)   #(rows, columns, second plot)
sns.scatterplot(x=df['mpg'], y=df['weightlbs'],data = df)

plt.subplot(2,2,3)   #(rows, columns, third plot)
sns.scatterplot(x=df['hp'], y=df['mpg'],data = df)

plt.subplot(2,2,4)   #(rows, columns, fourth plot)
sns.scatterplot(x=df['hp'], y=df['time-to-60'],data = df)
plt.title("hp vs time-to-60")
# Out:
# Text(0.5, 1.0, 'hp vs time-to-60')

# %%
fig = plt.subplots(2,2, figsize =(20,10))    #(row,columns, figsize=(width,height))
plt.subplot(2,2,1)   #(rows, columns, first plot)
sns.scatterplot(x=df['mpg'], y=df['hp'],data = df,marker='o',s= 50, hue=df['brand'])

plt.subplot(2,2,2)   #(rows, columns, second plot)
sns.scatterplot(x=df['mpg'], y=df['weightlbs'],data = df, hue=df['brand'])

plt.subplot(2,2,3)   #(rows, columns, third plot)
sns.scatterplot(x=df['hp'], y=df['mpg'],data = df, hue=df['brand'])

plt.subplot(2,2,4)   #(rows, columns, fourth plot)
sns.scatterplot(x=df['hp'], y=df['time-to-60'],data = df, hue=df['brand'])
plt.title("hp vs time-to-60")
# Out:
# Text(0.5, 1.0, 'hp vs time-to-60')

# %%
plt.scatter(x=df['mpg'], y=df['hp'])

# %% [markdown]
# 2. Create bar plots for the following, make sure all the plots appear in the same plane with
# x-labels and y-labels evenly spaced.
#
# a. Create a bar plot that shows the visual representation of hp, mpg, weight,
# time-to-60 with respect to the number of cylinders for each of the brands.
#
# b. Create a bar plot that shows the visual representation of hp, mpg, weight and
# time-to-60 with respect to the years, for each brand.

# %%
#a

fig = plt.subplots(2,2, figsize =(20,10))
plt.subplot(2,2,1)
sns.barplot(x=df['cylinders'],y=df['hp'],hue=df['brand'], data =df)

plt.subplot(2,2,2)
sns.barplot(x=df['cylinders'],y=df['mpg'], hue=df['brand'], data =df)

plt.subplot(2,2,3)
sns.barplot(x=df['cylinders'],y=df['weightlbs'], hue=df['brand'],data=df)

plt.subplot(2,2,4)
sns.barplot(x=df['cylinders'],y=df['time-to-60'], hue=df['brand'],data=df)
# Out:
# <Axes: xlabel='cylinders', ylabel='time-to-60'>

# %%
#b


fig = plt.subplots(2,2, figsize =(20,10))
plt.subplot(2,2,1)
sns.barplot(x=df['year'],y=df['hp'],hue=df['brand'], data =df)

plt.subplot(2,2,2)
sns.barplot(x=df['year'],y=df['mpg'], hue=df['brand'], data =df)

plt.subplot(2,2,3)
sns.barplot(x=df['year'],y=df['weightlbs'], hue=df['brand'],data=df)

plt.subplot(2,2,4)
sns.barplot(x=df['year'],y=df['time-to-60'], hue=df['brand'],data=df)
# Out:
# <Axes: xlabel='year', ylabel='time-to-60'>

# %% [markdown]
# 3. Create box plots for the following:
#
# a. Create box plots for the columns in the step1 with respect to the number of
# cylinders and brand respectively.

# %%
#y=mpg,hp,we,cy
#x=cylinder
#hue=brand


fig = plt.subplots(2,2, figsize =(20,10))
plt.subplot(2,2,1)
sns.boxplot(x=df['cylinders'],y=df['hp'],hue=df['brand'], data =df)

plt.subplot(2,2,2)
sns.boxplot(x=df['cylinders'],y=df['mpg'], hue=df['brand'], data =df)

plt.subplot(2,2,3)
sns.boxplot(x=df['cylinders'],y=df['weightlbs'], hue=df['brand'],data=df)

plt.subplot(2,2,4)
sns.boxplot(x=df['cylinders'],y=df['time-to-60'], hue=df['brand'],data=df)
# Out:
# <Axes: xlabel='cylinders', ylabel='time-to-60'>

# %% [markdown]
# 4. Create pair plots for the entire data to study various patterns in the data.
#
# a. Create pair plots with respect to brand, number of cylinders, year, etc.

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='brand')
